# %%
# Thien Tran 2022-Jun-09

# %%
size={
    "small": 2,
    "medium":3,
    "large":4
}
type_={
    "brewed":0,
    "espresso":0.5,
    "coldbrew": 1
}
flavoring={
    "none":0,
    "hazelnut":0.5,
    "vanilla":0.5,
    "caramel":0.5

}


questions=['size','type_','flavoring']
record=[]
for i in range(3):
  t = globals()[questions[i]]
  print("Please enter the {} of your coffee: ".format(questions[i]))
  print(t.keys())
  inp = input()
  inp = inp.lower()
  inp = inp.replace(" ","")
  while (inp.lower() not in t):
    print("Sorry, I don't recognize the {} option. Please try again!".format(questions[i]))
    inp = input()
    inp = inp.lower()
    inp = inp.replace(" ","")
  record.append(inp)

cost = 0
for i in range(3):
  t = globals()[questions[i]]
  cost += t[record[i]]
  print("The {} of your coffee is {}".format(questions[i],record[i]))
cost = cost*1.15
cost = round(cost,2)
print("The total cost with tips is ${}".format(cost) )
# Out:
# Please enter the size of your coffee:
# dict_keys(['small', 'medium', 'large'])
# large
# Please enter the type_ of your coffee:
# dict_keys(['brewed', 'espresso', 'coldbrew'])
# espresso
# Please enter the flavoring of your coffee:
# dict_keys(['none', 'hazelnut', 'vanilla', 'caramel'])
# vanilla
# The size of your coffee is large
# The type_ of your coffee is espresso
# The flavoring of your coffee is vanilla
# The total cost with tips is $5.75

# %%
#
